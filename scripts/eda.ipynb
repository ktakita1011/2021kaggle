# %%
import pandas as pd
from pathlib import Path
from rich import print

# %%
class Config:

    train_path = Path("/kaggle/input/home-credit-credit-risk-model-stability/csv_files/train")

# %%
train_base = pd.read_csv(Config.train_path.joinpath("train_base.csv"), nrows=100)

# %%
train_applprev_1_0 = pd.read_csv(Config.train_path.joinpath("train_applprev_1_0.csv"), nrows=100)
train_credit_bureau_a = pd.read_csv(Config.train_path.joinpath("train_credit_bureau_a_1_0.csv"), nrows=100)
train_credit_bureau_b = pd.read_csv(Config.train_path.joinpath("train_credit_bureau_b_1.csv"), nrows=100)
train_debitcard_1 = pd.read_csv(Config.train_path.joinpath("train_debitcard_1.csv"), nrows=100)
train_deposit_1 = pd.read_csv(Config.train_path.joinpath("train_deposit_1.csv"), nrows=100)
train_other_1 = pd.read_csv(Config.train_path.joinpath("train_other_1.csv"), nrows=100)
train_person_1 = pd.read_csv(Config.train_path.joinpath("train_person_1.csv"), nrows=100)
train_static_0_0 = pd.read_csv(Config.train_path.joinpath("train_static_0_0.csv"), nrows=100)
train_static_cb_0 = pd.read_csv(Config.train_path.joinpath("train_static_cb_0.csv"), nrows=100)
train_tax_registry_a_1 = pd.read_csv(Config.train_path.joinpath("train_tax_registry_a_1.csv"), nrows=100)
train_tax_registry_b_1 = pd.read_csv(Config.train_path.joinpath("train_tax_registry_b_1.csv"), nrows=100)
train_tax_registry_c_1 = pd.read_csv(Config.train_path.joinpath("train_tax_registry_c_1.csv"), nrows=100)

# %%
train_static_0_0 = pd.read_csv(Config.train_path.joinpath("train_static_0_0.csv"))
train_static_0_1 = pd.read_csv(Config.train_path.joinpath("train_static_0_1.csv"))
# Out:
# /tmp/ipykernel_152622/2164444914.py:1: DtypeWarning: Columns (20,45,46,53,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_static_0_0 = pd.read_csv(Config.train_path.joinpath("train_static_0_0.csv"))
# /tmp/ipykernel_152622/2164444914.py:2: DtypeWarning: Columns (20,45,46,56,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_static_0_1 = pd.read_csv(Config.train_path.joinpath("train_static_0_1.csv"))

# %%
train_static = pd.concat([train_static_0_0, train_static_0_1])

# %%
train_base = pd.read_csv(Config.train_path.joinpath("train_base.csv"))

# %%
len(train_base)
# Out:
# 1526659

# %%
train_base["case_id"]
# Out:
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#             ...
# 1526654    2703450
# 1526655    2703451
# 1526656    2703452
# 1526657    2703453
# 1526658    2703454
# Name: case_id, Length: 1526659, dtype: int64

# %%
# Out:
# 522902

# %%
print(train_static_0_0.iloc[50].to_dict())
# Out:
# {
#     'case_id': 50,
#     'actualdpdtolerance_344P': nan,
#     'amtinstpaidbefduel24m_4187115A': nan,
#     'annuity_780A': 5919.8003,
#     'annuitynextmonth_57A': 0.0,
#     'applicationcnt_361L': 0.0,
#     'applications30d_658L': 0.0,
#     'applicationscnt_1086L': 0.0,
#     'applicationscnt_464L': 0.0,
#     'applicationscnt_629L': 0.0,
#     'applicationscnt_867L': 0.0,
#     'avgdbddpdlast24m_3658932P': nan,
#     'avgdbddpdlast3m_4187120P': nan,
#     'avgdbdtollast24m_4525197P': nan,
#     'avgdpdtolclosure24_3658938P': nan,
#     'avginstallast24m_3658937A': nan,
#     'avglnamtstart24m_4525187A': nan,
#     'avgmaxdpdlast9m_3716943P': nan,
#     'avgoutstandbalancel6m_4187114A': nan,
#     'avgpmtlast12m_4525200A': nan,
#     'bankacctype_710L': 'CA',
#     'cardtype_51L': nan,
#     'clientscnt12m_3712952L': 0.0,
#     'clientscnt3m_3712950L': 0.0,
#     'clientscnt6m_3712949L': 0.0,
#     'clientscnt_100L': 0.0,
#     'clientscnt_1022L': 0.0,
# ...

# %%
print(train_static_cb_0.iloc[0].to_dict())
# Out:
# {
#     'case_id': 357,
#     'assignmentdate_238D': nan,
#     'assignmentdate_4527235D': nan,
#     'assignmentdate_4955616D': nan,
#     'birthdate_574D': '1988-04-01',
#     'contractssum_5085716L': nan,
#     'dateofbirth_337D': nan,
#     'dateofbirth_342D': nan,
#     'days120_123L': nan,
#     'days180_256L': nan,
#     'days30_165L': nan,
#     'days360_512L': nan,
#     'days90_310L': nan,
#     'description_5085714M': 'a55475b1',
#     'education_1103M': 'a55475b1',
#     'education_88M': 'a55475b1',
#     'firstquarter_103L': nan,
#     'for3years_128L': nan,
#     'for3years_504L': nan,
#     'for3years_584L': nan,
#     'formonth_118L': nan,
#     'formonth_206L': nan,
#     'formonth_535L': nan,
#     'forquarter_1017L': nan,
#     'forquarter_462L': nan,
#     'forquarter_634L': nan,
#     'fortoday_1092L': nan,
#     'forweek_1077L': nan,
#     'forweek_528L': nan,
#     'forweek_601L': nan,
#     'foryear_618L': nan,
#     'foryear_818L': nan,
# ...

# %%
print(train_applprev_1_0.iloc[50].to_dict())
# Out:
# {
#     'case_id': 54,
#     'actualdpd_943P': 0.0,
#     'annuity_853A': 6390.4,
#     'approvaldate_319D': nan,
#     'byoccupationinc_3656910L': 25000.0,
#     'cancelreason_3545846M': 'a55475b1',
#     'childnum_21L': 1.0,
#     'creationdate_885D': '2013-12-17',
#     'credacc_actualbalance_314A': nan,
#     'credacc_credlmt_575A': 0.0,
#     'credacc_maxhisbal_375A': nan,
#     'credacc_minhisbal_90A': nan,
#     'credacc_status_367L': nan,
#     'credacc_transactions_402L': nan,
#     'credamount_590A': 100000.0,
#     'credtype_587L': 'CAL',
#     'currdebt_94A': nan,
#     'dateactivated_425D': nan,
#     'district_544M': 'P116_67_156',
#     'downpmt_134A': 0.0,
#     'dtlastpmt_581D': nan,
#     'dtlastpmtallstes_3545839D': nan,
#     'education_1138M': 'P97_36_170',
#     'employedfrom_700D': '2008-04-15',
#     'familystate_726L': 'MARRIED',
#     'firstnonzeroinstldate_307D': '2014-01-17',
#     'inittransactioncode_279L': 'CASH',
#     'isbidproduct_390L': False,
# ...

# %%
print(train_credit_bureau_a.iloc[50].to_dict())
# Out:
# {
#     'case_id': 411,
#     'annualeffectiverate_199L': nan,
#     'annualeffectiverate_63L': nan,
#     'classificationofcontr_13M': 'a55475b1',
#     'classificationofcontr_400M': 'a55475b1',
#     'contractst_545M': 'a55475b1',
#     'contractst_964M': 'a55475b1',
#     'contractsum_5085717L': nan,
#     'credlmt_230A': nan,
#     'credlmt_935A': nan,
#     'dateofcredend_289D': nan,
#     'dateofcredend_353D': nan,
#     'dateofcredstart_181D': nan,
#     'dateofcredstart_739D': nan,
#     'dateofrealrepmt_138D': nan,
#     'debtoutstand_525A': nan,
#     'debtoverdue_47A': nan,
#     'description_351M': 'a55475b1',
#     'dpdmax_139P': nan,
#     'dpdmax_757P': nan,
#     'dpdmaxdatemonth_442T': nan,
#     'dpdmaxdatemonth_89T': nan,
#     'dpdmaxdateyear_596T': nan,
#     'dpdmaxdateyear_896T': nan,
#     'financialinstitution_382M': 'a55475b1',
#     'financialinstitution_591M': 'a55475b1',
#     'instlamount_768A': nan,
#     'instlamount_852A': nan,
# ...

# %%
print(train_person_1.iloc[50].to_dict())
# Out:
# {
#     'case_id': 13,
#     'birth_259D': nan,
#     'birthdate_87D': nan,
#     'childnum_185L': nan,
#     'contaddr_district_15M': 'a55475b1',
#     'contaddr_matchlist_1032L': nan,
#     'contaddr_smempladdr_334L': nan,
#     'contaddr_zipcode_807M': 'a55475b1',
#     'education_927M': 'a55475b1',
#     'empl_employedfrom_271D': nan,
#     'empl_employedtotal_800L': nan,
#     'empl_industry_691L': nan,
#     'empladdr_district_926M': 'a55475b1',
#     'empladdr_zipcode_114M': 'a55475b1',
#     'familystate_447L': nan,
#     'gender_992L': nan,
#     'housetype_905L': nan,
#     'housingtype_772L': nan,
#     'incometype_1044T': nan,
#     'isreference_387L': nan,
#     'language1_981M': 'a55475b1',
#     'mainoccupationinc_384A': nan,
#     'maritalst_703L': nan,
#     'num_group1': 1,
#     'personindex_1023L': 1.0,
#     'persontype_1072L': 5.0,
#     'persontype_792L': 5.0,
#     'registaddr_district_1083M': 'a55475b1',
#     'registaddr_zipcode_184M': 'a55475b1',
# ...
